# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os

auto = pd.read_csv('Automobile_data.csv')
auto = auto.head()

# %%
# plt.plot(auto['fuel-type'],auto['make'])
# plt.show()

# brandVSfuel=auto.groupby(['make','fuel-type']).size().unstack(fill_value=0)

# brandVSfuel.plot(kind='line',stacked=False)
brandVSdoor = auto.groupby(['make','num-of-doors']).size().unstack(fill_value=0)
brandVSdoor.plot(kind='bar',stacked=False)
# plt.show()
plt.figure(figsize=(20,8))
sns.lineplot(data=auto["wheel-base"],linewidth=1.5,label="Wheel Base")
sns.lineplot(data=auto['engine-size'],linewidth=1.5,label='Engine Size')

plt.title('Wheel Base VS Engine Size')
plt.ylabel('wheel Base')
plt.xlabel('Engine size')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# # Load the data
# auto = pd.read_csv('Automobile_data.csv')

# # Group by 'make' and 'price', and unstack the result
# auto['price'] = pd.to_numeric(auto['price'],errors='coerce')

# def price_of_cars(price):
#     if price >= 6000 and price <8000:
#        return 'under budget'
        
#     elif price >=8000 and price <10000:
#        return 'afford able'
#     elif price >=10000 and price < 25000:
#         return 'over budget'
        
#     elif price >=25000:
#         return 'luzury'
#     else:
#         return 'most expensive'
    

# # Check if the script is run directly

# auto['budget'] = auto['price'].apply(price_of_cars)
# auto
auto =pd.read_csv('Automobile_data.csv')
autoData = auto[['price','make']]
autoData['price'] = pd.to_numeric(autoData['price'],errors='coerce')

categories = { 
    'avg-car':(10000,15000),
    'above_avg':(15000,30000),
    'luxury':(30000,50000)
}

def fetch_budget(price):
    for category,(low,high) in categories.items():
        if low <=price <=high:
            return category
    return 'undefined'

autoData['budget'] = autoData['price'].apply(fetch_budget)

autoData
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_13192\271177665.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autoData['price'] = pd.to_numeric(autoData['price'],errors='coerce')
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_13192\271177665.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autoData['budget'] = autoData['price'].apply(fetch_budget)
#        price         make     budget
# 0    13495.0  alfa-romero    avg-car
# 1    16500.0  alfa-romero  above_avg
# 2    16500.0  alfa-romero  above_avg
# 3    13950.0         audi    avg-car
# 4    17450.0         audi  above_avg
# ..       ...          ...        ...
# 200  16845.0        volvo  above_avg
# 201  19045.0        volvo  above_avg
# 202  21485.0        volvo  above_avg
# 203  22470.0        volvo  above_avg
# 204  22625.0        volvo  above_avg
#
# [205 rows x 3 columns]

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=auto["wheel-base"],linewidth=1.5,label="Wheel Base")
sns.lineplot(data=auto['engine-size'],linewidth=1.5,label='Engine Size')

plt.title('Wheel Base VS Engine Size')
plt.ylabel('wheel Base')
plt.xlabel('Engine size')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.set(rc={"axes.facecolor":"#00F000","axes.grid":False,"xtick.labelsize":10,"ytick.labelsize":10})
plt.title('Wheel Base VS Engine Size')
plt.ylabel('wheel Base')
plt.xlabel('Engine size')
plt.xticks(rotation=45)
sns.lineplot(x=auto['engine-size'],y=auto['wheel-base'].index.values,color='r')
plt.show()
